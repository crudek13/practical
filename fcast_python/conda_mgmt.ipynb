# %%
import sys

# %% [markdown]
# List all packages in the current environment:

# %%
conda list
# Out:
# # packages in environment at c:\Users\crudek\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2023.03                  py39_0
# _ipyw_jlab_nb_ext_conf    0.1.0            py39haa95532_0
# _py-xgboost-mutex         2.0                       cpu_0
# abseil-cpp                20211102.0           hd77b12b_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# alembic                   1.8.1            py39haa95532_0
# anaconda                  custom                   py39_2
# anaconda-client           1.11.0           py39haa95532_0
# anaconda-navigator        2.3.1            py39haa95532_0
# anaconda-project          0.11.1           py39haa95532_0
# anyio                     3.5.0            py39haa95532_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h2bbff1b_0
# ...

# %% [markdown]
# Version of anaconda package

# %%
conda list scikit-learn$
# Out:
# # packages in environment at c:\Users\crudek\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              1.0.2            py39hf11a4ad_1
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Get info including python version

# %%
conda info
# Out:
#      active environment : base
#     active env location : C:\Users\crudek\Anaconda3
#             shell level : 1
#        user config file : C:\Users\crudek\.condarc
#  populated config files : C:\Users\crudek\.condarc
#           conda version : 22.9.0
#     conda-build version : 3.22.0
#          python version : 3.9.13.final.0
#        virtual packages : __cuda=11.6=0
#                           __win=0=0
#                           __archspec=1=x86_64
#        base environment : C:\Users\crudek\Anaconda3  (writable)
#       conda av data dir : C:\Users\crudek\Anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
# ...

# %% [markdown]
# Again, check for package

# %%
conda list pyarrow$
# Out:
# # packages in environment at c:\Users\crudek\Anaconda3:
# Note: you may need to restart the kernel to use updated packages.
#
# #
# # Name                    Version                   Build  Channel
# pyarrow                   6.0.0           py39ha05331a_5_cpu    conda-forge

# %% [markdown]
# If it doesnt exist, install package

# %%
# !conda install --yes --prefix {sys.prefix} sklearn
# Out:
# ...
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - sklearn
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#   - https://conda.anaconda.org/conda-forge/win-64
#   - https://conda.anaconda.org/conda-forge/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.

# %% [markdown]
# Certain Version

# %%
conda install pyarrow=6.0.0
# Out:
# ...
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\crudek\Anaconda3
#
#   added / updated specs:
#     - pyarrow=6.0.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.2      |       hd77b12b_0         1.6 MB
#     arrow-cpp-6.0.0            |py39h9cb858f_5_cpu        15.7 MB  conda-forge
#     aws-c-cal-0.5.11           |       he19cf47_0          36 KB  conda-forge
#     aws-c-common-0.6.2         |       h2bbff1b_0         156 KB
#     aws-c-event-stream-0.2.7   |      h70e1b0c_13          47 KB  conda-forge
#     aws-c-io-0.10.5            |       h2fe331c_0         127 KB  conda-forge
#     aws-checksums-0.1.11       |       h1e232aa_7          51 KB  conda-forge
# ...

# %% [markdown]
# ISSUE: package (pycaret) wasnt in the channels i had, so this helped. Channels are basically servers people host there packages on
#
# https://stackoverflow.com/questions/48493505/packagesnotfounderror-the-following-packages-are-not-available-from-current-cha
#
# conda config --append channels conda-forge
#
# This tells conda to also look on the conda-forge channel when you search for packages... this is usually a good place to start

# %% [markdown]
# Update packages

# %%
conda update pycaret
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/notices.json HTTP/1.1" 404 None
# ...

# %% [markdown]
# Remove package

# %%
conda remove pyarrow
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\crudek\Anaconda3
#
#   removed specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-navigator-2.4.2   |   py39haa95532_0         5.5 MB
#     jupyter_client-7.4.9       |   py39haa95532_0         224 KB
#     jupyter_server-1.23.4      |   py39haa95532_0         399 KB
#     notebook-6.5.4             |   py39haa95532_1         555 KB
#     numpy-1.25.0               |   py39h055cbcc_0          13 KB
#     numpy-base-1.25.0          |   py39h65a83cf_0         6.2 MB
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     ------------------------------------------------------------
#                                            Total:        12.9 MB
#
# The following packages will be REMOVED:
#
#   _anaconda_depends-2023.07-py39_0
# ...
